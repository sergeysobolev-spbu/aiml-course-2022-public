# %%
from math import sqrt
from collections import namedtuple

Point = namedtuple("Point", ['x', 'y'])
Facility = namedtuple("Facility", ['index', 'setup_cost', 'capacity', 'location'])
Customer = namedtuple("Customer", ['index', 'demand', 'location'])


def dist(p1, p2):
    return sqrt((p1.x-p2.x)**2 + (p1.y-p2.y)**2)


def parse_input(input_data):
    # parse the input
    lines = input_data.split('\n')

    parts = lines[0].split()
    facility_count = int(parts[0])
    customer_count = int(parts[1])

    facilities = []
    for i in range(1, facility_count+1):
        parts = lines[i].split()
        facilities.append(Facility(i-1, float(parts[0]), int(parts[1]), Point(float(parts[2]), float(parts[3])) ))

    customers = []
    for i in range(facility_count+1, facility_count+1+customer_count):
        parts = lines[i].split()
        customers.append(Customer(i-1-facility_count, int(parts[0]), Point(float(parts[1]), float(parts[2]))))

    return customers, facilities

# %% [markdown]
# %pip install pulp

# %%
import logging

class SolverBasic:
    def __init__(self):
        self.facilities = []
        self.customers = []
        self.logger = logging.getLogger('facility_planner')
        self.logger.setLevel(logging.DEBUG)
        self.log_file_name = 'solver.log'
        fh = logging.FileHandler(self.log_file_name, mode='w')
        fh.setLevel(logging.DEBUG)
        ch = logging.StreamHandler()
        ch.setLevel(logging.ERROR)
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        fh.setFormatter(formatter)
        ch.setFormatter(formatter)
        self.logger.addHandler(fh)
        self.logger.addHandler(ch)
        pass

    def solve(self, facilities, customers):
        # build a trivial solution
        # pack the facilities one by one until all the customers are served
        solution = [-1]*len(customers)
        capacity_remaining = [f.capacity for f in facilities]

        facility_index = 0
        for customer in customers:
            if capacity_remaining[facility_index] >= customer.demand:
                solution[customer.index] = facility_index
                capacity_remaining[facility_index] -= customer.demand
            else:
                facility_index += 1
                assert capacity_remaining[facility_index] >= customer.demand
                solution[customer.index] = facility_index
                capacity_remaining[facility_index] -= customer.demand

        used = [0]*len(facilities)
        for facility_index in solution:
            used[facility_index] = 1

        # calculate the cost of the solution
        obj = sum([f.setup_cost*used[f.index] for f in facilities])
        for customer in customers:
            obj += dist(customer.location, facilities[solution[customer.index]].location)

        return obj, solution

# %%
class SolverGreedy(SolverBasic):
    def init_model(self):
        pass

    def solve(self, facilities, customers):
        self.facilities = facilities
        self.customers = customers
        self.init_model()
        # TODO implement greedy algorithm
        pass

# %%
import pulp

class SolverPULP(SolverGreedy):
    def __init__(self):
        super().__init__()
        self.distances = []
        self.c2f = []  # customer to facility assignement
        self.f_d = []  # facility demands
        self.customers = []
        self.customers_count = 0
        self.facilities = []
        self.facilities_count = 0


    def calculate_dist(self, customer, facility):
        return dist(customer.location, facility.location)

    def calculate_dists(self):
        fc = len(self.facilities)
        cc = len(self.customers)
        self.distances = [[0]*fc for _ in range(cc)]
        for c in range(cc):
            for f in range(fc):
                self.distances[c][f] = self.calculate_dist(self.customers[c], self.facilities[f])
        # self.logger.debug(f"distances: {self.distances}")

    def input_feasibility_check(self):
        total_capacity = 0
        for f in self.facilities:
            total_capacity += f.capacity
        total_demand = 0
        for c in self.customers:
            total_demand += c.demand
        assert total_demand < total_capacity
        self.logger.debug(f"demand:{total_demand}, capacity:{total_capacity}")

    def output_feasibility_check(self):
        pass

    def init_model(self):
        # customers to facilities assignement
        if not self.facilities or not self.customers:
            return  # empty input, nothing to do

        self.customers_count = len(self.customers)
        self.facilities_count = len(self.facilities)

        self.input_feasibility_check()

        # customer to facility assignement martix
        self.c2f = [
            [
                pulp.LpVariable(
                    f"c{cn}_f{fn}", cat='Binary'
                    ) for fn, _ in enumerate(self.facilities)
            ] for cn, _ in enumerate(self.customers)
        ]
        # self.logger.debug(self.c2f)
        
        self.calculate_dists()
        # facility demand
        self.f_d = [
            pulp.LpVariable(
                f"f_d_{fn}", cat=pulp.LpContinuous, lowBound=0, upBound=f.capacity
            ) for fn, f in enumerate(self.facilities)
        ]
        
        # facility open binary
        self.f_o = [
            pulp.LpVariable(
                f"f_o_{fn}", cat=pulp.LpBinary
            ) for fn, _ in enumerate(self.facilities)
        ]
        # self.logger.debug(self.f_d)
        
        
        self.model = pulp.LpProblem("Cost_minimising_planning_problem", pulp.LpMinimize)
        
        # === objective function ===
        # sum of all distances to the open centre
        # add setup costs
        self.model += pulp.lpSum(
            [
                self.distances[cn][fn] * self.c2f[cn][fn]
                for cn in range(self.customers_count)
                for fn, f in enumerate(self.facilities)
            ] + [
                f.setup_cost * self.f_o[fn]
                for fn, f in enumerate(self.facilities)
            ]
        )
        # self.logger.debug(f"model: {self.model}")
        
        # === constraints definition ===
        
        if True:
            # set f_o if sum of assignments to it > 0
            sum_delta = []
        
            for fn in range(self.facilities_count):
                sum_a = 0
                for cn in range(self.customers_count):
                    sum_a += self.c2f[cn][fn]
                # condition if sum_a > 0 then set f_o to 1
                # https://math.stackexchange.com/questions/2500415/how-to-write-if-else-statement-in-linear-programming/2501007
                sum_delta.append(pulp.LpVariable(f"sum_delta{fn}", cat=pulp.LpBinary))
                self.model += sum_a >= - self.customers_count * (1-sum_delta[-1])
                self.model += sum_a <= self.customers_count * sum_delta[-1]
                self.model += 1 - self.customers_count*(1-sum_delta[-1]) <= self.f_o[fn]
                self.model += 1 + self.customers_count*(1-sum_delta[-1]) >= self.f_o[fn]
                self.model += - self.customers_count*sum_delta[-1] <= self.f_o[fn]
                self.model += self.customers_count*sum_delta[-1] >= self.f_o[fn]
        self.logger.debug(f"model: {self.model}")

        # sum demands <= facility capacity
        for fn,f in enumerate(self.facilities):
            sum_d = 0
            for cn, c in enumerate(self.customers):
                sum_d += c.demand * self.c2f[cn][fn]
            self.model += self.f_d[fn] == sum_d
            self.model += self.f_d[fn] <= f.capacity

        # each customer must be assigned to just one facility
        for cn in range(self.customers_count):
            self.model += pulp.lpSum([self.c2f[cn]]) == 1

        # should be not needed
        if False:
            for fn in range(self.facilities_count):
                sum_a = 0
                for cn in range(self.customers_count):
                    sum_a += self.c2f[cn][fn]
                self.model += sum_a <= self.customers_count
                    
    def process_results(self):
        # self.logger.debug(self.f_o)
        # self.logger.debug(self.c2f)
        obj = pulp.value(self.model.objective)
        self.logger.debug(f"objective val {obj}")
        # show which facilities are open
        for fn in range(self.facilities_count):
            f_o = pulp.value(self.f_o[fn])
            if f_o:
                self.logger.debug(f"f_o:{fn}=={f_o}")
            
        # show assignments of customers to facilities
        for cn in range(self.customers_count):
            for fn in range(self.facilities_count):
                assigned = pulp.value(self.c2f[cn][fn])
                if assigned:
                    self.logger.debug(f"c{cn}->f{fn}")
                
        # show total demand from each open facility from the solver
        for fn in range(self.facilities_count):
            f_d = pulp.value(self.f_d[fn])
            if f_d:
                self.logger.debug(f"f_d:{fn}={f_d}")
        # recalculate total demand based on assignments
        total_demand = 0
        for fn, f in enumerate(self.facilities):
            f_demand = 0
            for cn, c in enumerate(self.customers):
                assigned = pulp.value(self.c2f[cn][fn])
                if assigned == 1:
                    f_demand += c.demand
            total_demand += f_demand
                    # self.logger.debug(f"c{cn}f{fn}, demand={tdemand={total_demand}")
            self.logger.debug(f"f{fn} capacity={f.capacity}, demand={f_demand}")
        self.logger.debug(f"total demand={total_demand}")

        solution = []
        return obj, solution

    def solve(self, facilities, customers):
        self.facilities = facilities
        self.customers = customers
        self.model = None
        self.init_model()
        # TODO: implement PULP-based algorithm
        self.model.solve()
        self.logger.info(f"solving status: {pulp.LpStatus[self.model.status]}")
        self.process_results()
        obj = 0
        solution = []
        return obj, solution

# %%
def solve_it(input_data):
    # Modify this code to run your optimization algorithm

    # parse the input
    customers, facilities = parse_input(input_data)

    solver = SolverPULP()
    obj, solution = solver.solve(facilities, customers)

    # prepare the solution in the specified output format
    output_data = '%.2f' % obj + ' ' + str(0) + '\n'
    output_data += ' '.join(map(str, solution))

    return output_data

# %%
input_file = "data/facility_planning/fl_16_1"

# %%
with open(input_file, 'r') as input_data_file:
    input_data = input_data_file.read()
print(solve_it(input_data))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/8dd06fb2246749b3b3941c12cc981622-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/8dd06fb2246749b3b3941c12cc981622-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 183 COLUMNS
# At line 6055 RHS
# At line 6234 BOUNDS
# At line 7083 ENDATA
# Problem MODEL has 178 rows, 848 columns and 3392 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 3.36246e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 0 strengthened rows, 30 substitutions
# Cgl0004I processed model has 82 rows, 816 columns (816 integer (816 of which binary)) and 2416 elements
# Cbc0038I Initial state - 24 integers unsatisfied sum - 4.18719
# Cbc0038I Pass   1: suminf.    3.24859 (20) obj. 3.43149e+06 iterations 34
# Cbc0038I Pass   2: suminf.    1.51464 (11) obj. 3.68689e+06 iterations 69
# Cbc0038I Pass   3: suminf.    1.42580 (9) obj. 3.69106e+06 iterations 5
# Cbc0038I Pass   4: suminf.    2.09855 (11) obj. 3.68128e+06 iterations 31
# Cbc0038I Pass   5: suminf.    1.25597 (9) obj. 3.67145e+06 iterations 14
# Cbc0038I Pass   6: suminf.    1.93473 (10) obj. 3.68073e+06 iterations 34
# Cbc0038I Pass   7: suminf.    1.66152 (17) obj. 5.76881e+06 iterations 143
# Cbc0038I Pass   8: suminf.    1.29953 (12) obj. 5.74643e+06 iterations 66
# Cbc0038I Pass   9: suminf.    1.41467 (6) obj. 5.65479e+06 iterations 53
# Cbc0038I Pass  10: suminf.    0.90136 (5) obj. 5.67316e+06 iterations 32
# Cbc0038I Pass  11: suminf.    0.90136 (4) obj. 5.68114e+06 iterations 8
# Cbc0038I Pass  12: suminf.    1.31813 (8) obj. 6.20774e+06 iterations 99
# Cbc0038I Pass  13: suminf.    0.64439 (8) obj. 6.1665e+06 iterations 62
# Cbc0038I Pass  14: suminf.    1.77824 (6) obj. 6.20204e+06 iterations 54
# Cbc0038I Pass  15: suminf.    1.77824 (6) obj. 6.20204e+06 iterations 3
# Cbc0038I Pass  16: suminf.    1.52323 (6) obj. 6.25111e+06 iterations 33
# Cbc0038I Pass  17: suminf.    1.52323 (5) obj. 6.25497e+06 iterations 3
# Cbc0038I Pass  18: suminf.    1.77824 (6) obj. 6.20204e+06 iterations 38
# Cbc0038I Pass  19: suminf.    2.72081 (16) obj. 6.82805e+06 iterations 119
# Cbc0038I Pass  20: suminf.    1.49271 (13) obj. 6.84124e+06 iterations 85
# Cbc0038I Pass  21: suminf.    1.11529 (6) obj. 6.82764e+06 iterations 67
# Cbc0038I Pass  22: suminf.    0.44463 (2) obj. 6.82775e+06 iterations 8
# Cbc0038I Pass  23: suminf.    0.64862 (3) obj. 6.77763e+06 iterations 38
# Cbc0038I Pass  24: suminf.    0.56555 (3) obj. 6.8517e+06 iterations 40
# Cbc0038I Pass  25: suminf.    0.56555 (2) obj. 6.85366e+06 iterations 1
# Cbc0038I Pass  26: suminf.    2.73157 (15) obj. 7.03808e+06 iterations 115
# Cbc0038I Pass  27: suminf.    1.33054 (11) obj. 7.09481e+06 iterations 72
# Cbc0038I Pass  28: suminf.    1.72751 (7) obj. 6.97179e+06 iterations 56
# Cbc0038I Pass  29: suminf.    1.72751 (7) obj. 6.97179e+06 iterations 2
# Cbc0038I Pass  30: suminf.    1.05718 (4) obj. 6.85195e+06 iterations 53
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 610 integers at bound fixed and 1 continuous
# Cbc0038I Full problem 82 rows 816 columns, reduced to 69 rows 196 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to 3.59043e+06 (0.12 seconds)
# Cbc0038I Round again with cutoff of 3.56837e+06
# Cbc0038I Reduced cost fixing fixed 38 variables on major pass 2
# Cbc0038I Pass  30: suminf.    3.24859 (20) obj. 3.43149e+06 iterations 0
# Cbc0038I Pass  31: suminf.    2.26007 (12) obj. 3.56837e+06 iterations 48
# Cbc0038I Pass  32: suminf.    1.43865 (10) obj. 3.56837e+06 iterations 9
# Cbc0038I Pass  33: suminf.    2.47189 (10) obj. 3.56837e+06 iterations 54
# Cbc0038I Pass  34: suminf.    1.09882 (9) obj. 3.56837e+06 iterations 30
# Cbc0038I Pass  35: suminf.    1.67781 (9) obj. 3.54099e+06 iterations 58
# Cbc0038I Pass  36: suminf.    0.89728 (4) obj. 3.54053e+06 iterations 30
# Cbc0038I Pass  37: suminf.    0.96189 (2) obj. 3.56837e+06 iterations 25
# Cbc0038I Pass  38: suminf.    0.57374 (2) obj. 3.55424e+06 iterations 45
# Cbc0038I Pass  39: suminf.    5.18853 (20) obj. 3.56837e+06 iterations 65
# Cbc0038I Pass  40: suminf.    3.51640 (16) obj. 3.56837e+06 iterations 31
# Cbc0038I Pass  41: suminf.    3.51640 (16) obj. 3.56837e+06 iterations 2
# Cbc0038I Pass  42: suminf.    2.71701 (9) obj. 3.56837e+06 iterations 51
# Cbc0038I Pass  43: suminf.    1.54336 (7) obj. 3.56837e+06 iterations 23
# Cbc0038I Pass  44: suminf.    2.25607 (7) obj. 3.56837e+06 iterations 29
# Cbc0038I Pass  45: suminf.    2.04799 (8) obj. 3.56837e+06 iterations 51
# Cbc0038I Pass  46: suminf.    2.17038 (7) obj. 3.56837e+06 iterations 38
# Cbc0038I Pass  47: suminf.    1.92520 (9) obj. 3.56837e+06 iterations 33
# Cbc0038I Pass  48: suminf.    1.98872 (10) obj. 3.56837e+06 iterations 27
# Cbc0038I Pass  49: suminf.    1.73396 (9) obj. 3.56837e+06 iterations 19
# Cbc0038I Pass  50: suminf.    3.08443 (11) obj. 3.56837e+06 iterations 34
# Cbc0038I Pass  51: suminf.    2.58374 (10) obj. 3.56837e+06 iterations 7
# Cbc0038I Pass  52: suminf.    2.57050 (10) obj. 3.56837e+06 iterations 28
# Cbc0038I Pass  53: suminf.    2.24140 (9) obj. 3.56837e+06 iterations 7
# Cbc0038I Pass  54: suminf.    3.44304 (15) obj. 3.56837e+06 iterations 65
# Cbc0038I Pass  55: suminf.    2.60602 (15) obj. 3.56837e+06 iterations 27
# Cbc0038I Pass  56: suminf.    2.76200 (9) obj. 3.56837e+06 iterations 62
# Cbc0038I Pass  57: suminf.    2.34054 (8) obj. 3.56837e+06 iterations 13
# Cbc0038I Pass  58: suminf.    2.54391 (7) obj. 3.56837e+06 iterations 65
# Cbc0038I Pass  59: suminf.    1.47212 (5) obj. 3.56837e+06 iterations 16
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 721 integers at bound fixed and 1 continuous
# Cbc0038I Full problem 82 rows 816 columns, reduced to 32 rows 74 columns
# Cbc0038I Mini branch and bound improved solution from 3.59043e+06 to 3.55993e+06 (0.20 seconds)
# Cbc0038I Round again with cutoff of 3.52191e+06
# Cbc0038I Reduced cost fixing fixed 63 variables on major pass 3
# Cbc0038I Pass  59: suminf.    3.24859 (20) obj. 3.43149e+06 iterations 0
# Cbc0038I Pass  60: suminf.    2.52333 (12) obj. 3.52191e+06 iterations 46
# Cbc0038I Pass  61: suminf.    1.66714 (11) obj. 3.50861e+06 iterations 44
# Cbc0038I Pass  62: suminf.    2.03749 (11) obj. 3.52191e+06 iterations 39
# Cbc0038I Pass  63: suminf.    1.33498 (9) obj. 3.52191e+06 iterations 11
# Cbc0038I Pass  64: suminf.    2.27804 (9) obj. 3.52191e+06 iterations 51
# Cbc0038I Pass  65: suminf.    1.46255 (9) obj. 3.52191e+06 iterations 12
# Cbc0038I Pass  66: suminf.    1.18335 (9) obj. 3.52191e+06 iterations 7
# Cbc0038I Pass  67: suminf.    1.75595 (9) obj. 3.52191e+06 iterations 42
# Cbc0038I Pass  68: suminf.    1.73672 (8) obj. 3.52191e+06 iterations 12
# Cbc0038I Pass  69: suminf.    1.56582 (6) obj. 3.52191e+06 iterations 19
# Cbc0038I Pass  70: suminf.    1.13381 (8) obj. 3.52191e+06 iterations 28
# Cbc0038I Pass  71: suminf.    1.78975 (9) obj. 3.52191e+06 iterations 18
# Cbc0038I Pass  72: suminf.    1.53744 (5) obj. 3.52191e+06 iterations 9
# Cbc0038I Pass  73: suminf.    1.05981 (5) obj. 3.52191e+06 iterations 52
# Cbc0038I Pass  74: suminf.    1.04466 (4) obj. 3.52191e+06 iterations 2
# Cbc0038I Pass  75: suminf.    1.55255 (7) obj. 3.52191e+06 iterations 48
# Cbc0038I Pass  76: suminf.    1.86594 (6) obj. 3.52191e+06 iterations 21
# Cbc0038I Pass  77: suminf.    3.71494 (15) obj. 3.52191e+06 iterations 53
# Cbc0038I Pass  78: suminf.    2.45919 (10) obj. 3.52191e+06 iterations 34
# Cbc0038I Pass  79: suminf.    2.45919 (10) obj. 3.52191e+06 iterations 2
# Cbc0038I Pass  80: suminf.    3.53170 (11) obj. 3.52191e+06 iterations 29
# Cbc0038I Pass  81: suminf.    2.48894 (9) obj. 3.52191e+06 iterations 13
# Cbc0038I Pass  82: suminf.    2.48503 (9) obj. 3.52191e+06 iterations 41
# Cbc0038I Pass  83: suminf.    3.02463 (9) obj. 3.52191e+06 iterations 20
# Cbc0038I Pass  84: suminf.    2.20857 (11) obj. 3.52191e+06 iterations 4
# Cbc0038I Pass  85: suminf.    1.97520 (9) obj. 3.52191e+06 iterations 7
# Cbc0038I Pass  86: suminf.    2.12539 (10) obj. 3.52191e+06 iterations 41
# Cbc0038I Pass  87: suminf.    1.65708 (10) obj. 3.52191e+06 iterations 20
# Cbc0038I Pass  88: suminf.    2.18931 (10) obj. 3.52191e+06 iterations 48
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 741 integers at bound fixed and 1 continuous
# Cbc0038I Full problem 82 rows 816 columns, reduced to 23 rows 48 columns
# Cbc0038I Mini branch and bound did not improve solution (0.25 seconds)
# Cbc0038I After 0.25 seconds - Feasibility pump exiting with objective of 3.55993e+06 - took 0.20 seconds
# Cbc0012I Integer solution of 3559933.4 found by feasibility pump after 0 iterations and 0 nodes (0.25 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 6 rows 11 columns
# Cbc0031I 47 added rows had average density of 26.595745
# Cbc0013I At root node, 47 cuts changed objective from 3369812.3 to 3509789.2 in 12 passes
# Cbc0014I Cut generator 0 (Probing) - 268 row cuts average 18.1 elements, 22 column cuts (22 active)  in 0.022 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 7 row cuts average 110.4 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 38 row cuts average 4.5 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 33 row cuts average 66.9 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 37 row cuts average 221.5 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 12 row cuts average 17.9 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 3559933.4 best solution, best possible 3509789.2 (0.35 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 9 rows 22 columns
# Cbc0038I Full problem 129 rows 816 columns, reduced to 80 rows 497 columns - too large
# Cbc0038I Full problem 82 rows 816 columns, reduced to 6 rows 18 columns
# Cbc0038I Full problem 82 rows 816 columns, reduced to 5 rows 17 columns
# Cbc0004I Integer solution of 3554700.5 found after 1665 iterations and 205 nodes (0.76 seconds)
# Cbc0004I Integer solution of 3554491.5 found after 2145 iterations and 262 nodes (0.85 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 9 rows 23 columns
# Cbc0038I Full problem 82 rows 816 columns, reduced to 6 rows 15 columns
# Cbc0016I Integer solution of 3554089.8 found by strong branching after 3698 iterations and 581 nodes (1.13 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 6 rows 12 columns
# Cbc0038I Full problem 82 rows 816 columns, reduced to 7 rows 18 columns
# Cbc0016I Integer solution of 3553731.2 found by strong branching after 5293 iterations and 905 nodes (1.38 seconds)
# Cbc0010I After 1000 nodes, 114 on tree, 3553731.2 best solution, best possible 3509789.2 (1.43 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 7 rows 18 columns
# Cbc0038I Full problem 82 rows 816 columns, reduced to 8 rows 17 columns
# Cbc0038I Full problem 82 rows 816 columns, reduced to 5 rows 16 columns
# Cbc0010I After 2000 nodes, 136 on tree, 3553731.2 best solution, best possible 3509789.2 (2.49 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 8 rows 21 columns
# Cbc0010I After 3000 nodes, 137 on tree, 3553731.2 best solution, best possible 3509789.2 (3.52 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 6 rows 14 columns
# Cbc0010I After 4000 nodes, 144 on tree, 3553731.2 best solution, best possible 3509789.2 (4.43 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 7 rows 19 columns
# Cbc0010I After 5000 nodes, 130 on tree, 3553731.2 best solution, best possible 3509789.2 (5.34 seconds)
# Cbc0004I Integer solution of 3551816.6 found after 33894 iterations and 5090 nodes (5.40 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 6 rows 16 columns
# Cbc0004I Integer solution of 3550799.6 found after 37651 iterations and 5761 nodes (6.01 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 5 rows 14 columns
# Cbc0010I After 6000 nodes, 246 on tree, 3550799.6 best solution, best possible 3509789.2 (6.24 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 6 rows 15 columns
# Cbc0010I After 7000 nodes, 272 on tree, 3550799.6 best solution, best possible 3509789.2 (7.26 seconds)
# Cbc0004I Integer solution of 3549749 found after 47210 iterations and 7296 nodes (7.52 seconds)
# Cbc0004I Integer solution of 3549492.6 found after 48284 iterations and 7504 nodes (7.67 seconds)
# Cbc0004I Integer solution of 3549336.6 found after 50324 iterations and 7764 nodes (7.94 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 6 rows 16 columns
# Cbc0010I After 8000 nodes, 236 on tree, 3549336.6 best solution, best possible 3509789.2 (8.22 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 5 rows 11 columns
# Cbc0038I Full problem 82 rows 816 columns, reduced to 3 rows 12 columns
# Cbc0010I After 9000 nodes, 200 on tree, 3549336.6 best solution, best possible 3509789.2 (9.02 seconds)
# Cbc0010I After 10000 nodes, 222 on tree, 3549336.6 best solution, best possible 3509789.2 (10.02 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 10 rows 26 columns
# Cbc0010I After 11000 nodes, 215 on tree, 3549336.6 best solution, best possible 3509789.2 (11.07 seconds)
# Cbc0012I Integer solution of 3541827.2 found by DiveCoefficient after 73944 iterations and 11014 nodes (11.20 seconds)
# Cbc0010I After 12000 nodes, 61 on tree, 3541827.2 best solution, best possible 3512751.8 (12.24 seconds)
# Cbc0012I Integer solution of 3538933.2 found by DiveCoefficient after 82104 iterations and 12058 nodes (12.54 seconds)
# Cbc0012I Integer solution of 3538523.2 found by DiveCoefficient after 88523 iterations and 12639 nodes (13.71 seconds)
# Cbc0010I After 13000 nodes, 442 on tree, 3538523.2 best solution, best possible 3514018.5 (14.19 seconds)
# Cbc0004I Integer solution of 3530672.6 found after 92132 iterations and 13067 nodes (14.24 seconds)
# Cbc0016I Integer solution of 3530530 found by strong branching after 92599 iterations and 13099 nodes (14.31 seconds)
# Cbc0004I Integer solution of 3525609.1 found after 92927 iterations and 13148 nodes (14.35 seconds)
# Cbc0004I Integer solution of 3523677.9 found after 97375 iterations and 13634 nodes (14.82 seconds)
# Cbc0010I After 14000 nodes, 140 on tree, 3523677.9 best solution, best possible 3514067.6 (15.10 seconds)
# Cbc0038I Full problem 82 rows 816 columns, reduced to 5 rows 12 columns
# Cbc0001I Search completed - best objective 3523677.87316781, took 107602 iterations and 14796 nodes (15.74 seconds)
# Cbc0032I Strong branching done 21440 times (103297 iterations), fathomed 1939 nodes and fixed 4830 variables
# Cbc0035I Maximum depth 57, 125326 variables fixed on reduced cost
# Cuts at root node changed objective from 3.36981e+06 to 3.50979e+06
# Probing was tried 4313 times and created 13610 cuts of which 0 were active after adding rounds of cuts (0.545 seconds)
# Gomory was tried 3854 times and created 65 cuts of which 0 were active after adding rounds of cuts (0.540 seconds)
# Knapsack was tried 3863 times and created 10983 cuts of which 0 were active after adding rounds of cuts (1.553 seconds)
# Clique was tried 12 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3863 times and created 158 cuts of which 0 were active after adding rounds of cuts (0.492 seconds)
# FlowCover was tried 12 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 12 times and created 37 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 12 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# ImplicationCuts was tried 458 times and created 370 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3523677.87316781
# Enumerated nodes:               14796
# Total iterations:               107602
# Time (CPU seconds):             15.10
# Time (Wallclock seconds):       15.74
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       15.10   (Wallclock seconds):       15.75
#
# 0.00 0
